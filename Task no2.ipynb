# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("BooksDataFrame.csv")

# %%
df.head()
# Out:
#                                    Title  Price            Category  \
# 0                   A Light in the Attic  51.77              Poetry
# 1                     Tipping the Velvet  53.74  Historical Fiction
# 2                             Soumission  50.10             Fiction
# 3                          Sharp Objects  47.82             Mystery
# 4  Sapiens: A Brief History of Humankind  54.23             History
#
#       Status  Stock Count Rating               UPC
# 0  In stock            22  Three  a897fe39b1053632
# 1  In stock            20    One  90fa61229261140a
# 2  In stock            20    One  6957f44c3847a760
# 3  In stock            20   Four  e00eb4fd7b871a48
# 4  In stock            20   Five  4165285e1663650f

# %%
df.tail()
# Out:
#                                                  Title  Price  \
# 995  Alice in Wonderland (Alice's Adventures in Won...  55.53
# 996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)  57.06
# 997  A Spy's Devotion (The Regency Spies of London #1)  16.97
# 998                1st to Die (Women's Murder Club #1)  53.98
# 999                 1,000 Places to See Before You Die  26.08
#
#                Category     Status  Stock Count Rating               UPC
# 995            Classics  In stock             1    One  cd2a2a70dd5d176d
# 996      Sequential Art  In stock             1   Four  bfd5e1701c862ac3
# 997  Historical Fiction  In stock             1   Five  19fec36a1dfb4c16
# 998             Mystery  In stock             1    One  f684a82adc49f011
# 999              Travel  Out stock            1   Five  228ba5e7577e1d49

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        1000 non-null   object
#  1   Price        1000 non-null   float64
#  2   Category     1000 non-null   object
#  3   Status       1000 non-null   object
#  4   Stock Count  1000 non-null   int64
#  5   Rating       1000 non-null   object
#  6   UPC          1000 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 54.8+ KB

# %%
df.shape
# Out:
# (1000, 7)

# %%
df.describe()
# Out:
#             Price  Stock Count
# count  1000.00000  1000.000000
# mean     35.07035     8.585000
# std      14.44669     5.654622
# min      10.00000     1.000000
# 25%      22.10750     3.000000
# 50%      35.98000     7.000000
# 75%      47.45750    14.000000
# max      59.99000    22.000000

# %%
# Convert Ratings from text to numeric
rating_map = {"One":1, "Two":2, "Three":3, "Four":4, "Five":5}
df['Rating'] = df['Rating'].map(rating_map)

# %%
df
# Out:
#                                                  Title  Price  \
# 0                                 A Light in the Attic  51.77
# 1                                   Tipping the Velvet  53.74
# 2                                           Soumission  50.10
# 3                                        Sharp Objects  47.82
# 4                Sapiens: A Brief History of Humankind  54.23
# ..                                                 ...    ...
# 995  Alice in Wonderland (Alice's Adventures in Won...  55.53
# 996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)  57.06
# 997  A Spy's Devotion (The Regency Spies of London #1)  16.97
# 998                1st to Die (Women's Murder Club #1)  53.98
# 999                 1,000 Places to See Before You Die  26.08
#
#                Category     Status  Stock Count  Rating               UPC
# 0                Poetry  In stock            22       3  a897fe39b1053632
# 1    Historical Fiction  In stock            20       1  90fa61229261140a
# 2               Fiction  In stock            20       1  6957f44c3847a760
# 3               Mystery  In stock            20       4  e00eb4fd7b871a48
# 4               History  In stock            20       5  4165285e1663650f
# ..                  ...        ...          ...     ...               ...
# 995            Classics  In stock             1       1  cd2a2a70dd5d176d
# 996      Sequential Art  In stock             1       4  bfd5e1701c862ac3
# 997  Historical Fiction  In stock             1       5  19fec36a1dfb4c16
# 998             Mystery  In stock             1       1  f684a82adc49f011
# 999              Travel  Out stock            1       5  228ba5e7577e1d49
#
# [1000 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        1000 non-null   object
#  1   Price        1000 non-null   float64
#  2   Category     1000 non-null   object
#  3   Status       1000 non-null   object
#  4   Stock Count  1000 non-null   int64
#  5   Rating       1000 non-null   int64
#  6   UPC          1000 non-null   object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 54.8+ KB

# %%
# Missing values per column
print(df.isnull().sum())
# Out:
# Title          0
# Price          0
# Category       0
# Status         0
# Stock Count    0
# Rating         0
# UPC            0
# dtype: int64

# %%
# Number of duplicate rows
print(df.duplicated().sum())
# Out:
# 0

# %%
#per category counts
df['Category'].value_counts()
# Out:
# Category
# Default               152
# Nonfiction            110
# Sequential Art         75
# Add a comment          67
# Fiction                65
# Young Adult            54
# Fantasy                48
# Romance                35
# Mystery                32
# Food and Drink         30
# Childrens              29
# Historical Fiction     26
# Poetry                 19
# Classics               19
# History                18
# Horror                 17
# Womens Fiction         17
# Science Fiction        16
# Science                14
# Music                  13
# Business               12
# Thriller               11
# Travel                 11
# Philosophy             11
# Humor                  10
# Autobiography           9
# Art                     8
# Psychology              7
# Religion                7
# Spirituality            6
# Christian Fiction       6
# New Adult               6
# Sports and Games        5
# Biography               5
# Self Help               5
# Health                  4
# Christian               3
# Politics                3
# Contemporary            3
# Historical              2
# Crime                   1
# Erotica                 1
# Cultural                1
# Novels                  1
# Short Stories           1
# Suspense                1
# Academic                1
# Adult Fiction           1
# Parenting               1
# Paranormal              1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.hist(bins=50)
# Out:
# array([[<Axes: title={'center': 'Price'}>,
#         <Axes: title={'center': 'Stock Count'}>],
#        [<Axes: title={'center': 'Rating'}>, <Axes: >]], dtype=object)

# %%
df.nunique()
# Out:
# Title           999
# Price           903
# Category         50
# Status            2
# Stock Count      21
# Rating            5
# UPC            1000
# dtype: int64

# %%
# Correlation matrix for numeric columns
df.corr(numeric_only=True)
# Out:
#                 Price  Stock Count    Rating
# Price        1.000000    -0.010914  0.028166
# Stock Count -0.010914     1.000000  0.016166
# Rating       0.028166     0.016166  1.000000

# %%
# Cross-tab analysis (relationship between categories and ratings)
pd.crosstab(df['Category'], df['Rating'])
# Out:
# Rating               1   2   3   4   5
# Category
# Academic             0   1   0   0   0
# Add a comment       16  13  17  13   8
# Adult Fiction        0   0   0   0   1
# Art                  0   1   2   4   1
# Autobiography        2   3   0   1   3
# Biography            1   2   2   0   0
# Business             3   2   3   1   3
# Childrens            8   5   9   4   3
# Christian            1   1   0   0   1
# Christian Fiction    0   1   0   2   3
# Classics             3   8   4   4   0
# Contemporary         2   0   0   0   1
# Crime                1   0   0   0   0
# Cultural             1   0   0   0   0
# Default             33  40  27  23  29
# Erotica              0   0   0   0   1
# Fantasy              9   9   9  11  10
# Fiction             13   6  19  10  17
# Food and Drink       7   6   7   3   7
# Health               0   1   1   0   2
# Historical           1   0   0   0   1
# Historical Fiction   5   4   5   4   8
# History              3   5   4   2   4
# Horror               4   4   4   3   2
# Humor                2   1   2   1   4
# Music                2   3   3   1   4
# Mystery              7   5   8   7   5
# New Adult            1   1   2   0   2
# Nonfiction          24  23  25  18  20
# Novels               0   0   0   0   1
# Paranormal           1   0   0   0   0
# Parenting            0   1   0   0   0
# Philosophy           6   1   0   2   2
# Poetry               3   2   2   6   6
# Politics             1   1   0   1   0
# Psychology           4   1   2   0   0
# Religion             1   1   2   2   1
# Romance             11   4  11   5   4
# Science              4   2   1   5   2
# Science Fiction      7   4   0   4   1
# Self Help            2   0   2   0   1
# Sequential Art      13  17  16  17  12
# Short Stories        1   0   0   0   0
# Spirituality         1   2   0   0   3
# Sports and Games     1   1   1   1   1
# Suspense             0   0   1   0   0
# Thriller             3   3   1   2   2
# Travel               2   3   3   2   1
# Womens Fiction       5   1   2   5   4
# Young Adult         11   7   6  15  15

# %%
pd.crosstab(df['Status'], df['Rating'])
# Out:
# Rating       1    2    3    4    5
# Status
# In stock   204  170  174  158  168
# Out stock   22   26   29   21   28

# %%
df['UPC'].nunique()
# Out:
# 1000
